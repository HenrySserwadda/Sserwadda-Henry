# %%
#create a machine learning model that can predict profit based on sales and other features,(regression task)
#Predict customer type based on trasactions and other features,(classification task)

# %%
#step1 :Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#import sci kit for machine learning

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
#step2 :Load the dataset and explore the EDA(Exploratory Data Analysis)
df = pd.read_csv('ecommerce_bigdata.csv')
df.head()
# Out:
#   TransactionID        Date    Region     ProductCategory CustomerType  Sales  \
# 0        TX0001  2026-06-16   Eastern         Electronics    Wholesale   4924
# 1        TX0002  2026-02-12   Central         Electronics       Retail   3283
# 2        TX0003  2026-03-01  Northern                Food       Online   4049
# 3        TX0004  2026-06-03   Western  Household Products       Online   4331
# 4        TX0005  2026-01-21   Western  Household Products       Retail   3283
#
#    Profit
# 0  359.44
# 1  944.32
# 2  967.10
# 3  434.57
# 4  340.48

# %%
#preprocess the data(handle missing values, encode categorical variables, scale numerical features  )
#check for empty values in the dataset
#check for duplicate values in the dataset

#check for missing values
df.isnull().sum()
# Out:
# TransactionID      0
# Date               0
# Region             0
# ProductCategory    0
# CustomerType       0
# Sales              0
# Profit             0
# dtype: int64

# %%
#summary of the statistics of the dataset
df.describe()
# Out:
#              Sales       Profit
# count   200.000000   200.000000
# mean   2567.190000   456.367350
# std    1528.736925   346.853151
# min      56.000000     5.130000
# 25%    1200.500000   173.967500
# 50%    2428.000000   379.330000
# 75%    4052.000000   675.000000
# max    4998.000000  1377.040000

# %%
#data visualization
#setup the plotting style
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(10,6))

# %%
#distribution of sales
sns.histplot(df['Sales'], bins=30, kde=True, ax=ax)
ax.set_title('Distribution of Sales')
ax.set_xlabel('Sales')
ax.set_ylabel('Frequency')
# Out:
# Text(4.444444444444452, 0.5, 'Frequency')
